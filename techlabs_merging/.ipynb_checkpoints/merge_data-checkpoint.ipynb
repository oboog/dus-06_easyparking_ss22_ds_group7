# %% [markdown]
# In this notebook we will merge files from different json and csv files about parking in Cologne.

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ###  Disabled parking data

# %%
def parse_features(features: list):
    return [{**feature['attributes'], **feature['geometry']} for feature in features]

# %%
with open("disabled.json", "r") as fp:
    disabled_parking = json.load(fp)

df_disabled_parking = pd.DataFrame.from_dict(parse_features(disabled_parking['features']))
df_disabled_parking['type'] = 'disabled parking slot'
df_disabled_parking
# Out:
#      objectid                     bezeichnung nr_stadtbezirk   stadtteil  \
# 0           1            Am Schwanebitzer Hof              7      Urbach
# 1           2                  DÃ¼lkenstr. 18              7        Porz
# 2           3            Friedrich-Ebert-Ufer              7        Porz
# 3           4                     GÃ¼tergasse              7    ZÃ¼ndorf
# 4           5  Heidestr. (vor Raiffeisenbank)              7        Wahn
# ..        ...                             ...            ...         ...
# 420      6727                    Friedhofsweg              3  Lindenthal
# 421      6728                  Gleueler Str.               3  Lindenthal
# 422      7128       Schanzenstr. (vor E-Werk)              9    MÃ¼lheim
# 423      7129              HÃ¶ninger Platz 25              2   Zollstock
# 424      7528            Hermann-PÃ¼nder-Str.              1       Deutz
#
#      anzahl                        bemerkung         x          y  \
# 0         1             Am Schwanebitzer Hof  7.080333  50.882116
# 1         2                   DÃ¼lkenstr. 18  7.052518  50.890363
# 2         1             Friedrich-Ebert-Ufer  7.054507  50.883369
# 3         1                      GÃ¼tergasse  7.045460  50.869548
# 4         1   Heidestr. (vor Raiffeisenbank)  7.087442  50.857666
# ..      ...                              ...       ...        ...
# 420       1  Am Eingang Friedhof Widdersdorf  6.829348  50.964770
# 421       1        Gleueler Str. vor Unireha  6.916132  50.926327
# 422       1        Schanzenstr. (vor E-Werk)  7.015854  50.969218
# 423       1               HÃ¶ninger Platz 25  6.944058  50.900591
# 424       2             Hermann-PÃ¼nder-Str.  6.970285  50.939845
#
#                       type
# 0    disabled parking slot
# 1    disabled parking slot
# 2    disabled parking slot
# 3    disabled parking slot
# 4    disabled parking slot
# ..                     ...
# 420  disabled parking slot
# 421  disabled parking slot
# 422  disabled parking slot
# 423  disabled parking slot
# 424  disabled parking slot
#
# [425 rows x 9 columns]

# %%
with open("parkhaus.json", "r") as fp:
    parking_garages = json.load(fp)

df_parking_garages = pd.DataFrame.from_dict(parse_features(parking_garages['features']))
df_parking_garages['type'] = 'parking garage'
df_parking_garages
# Out:
#    identifier                                           parkhaus  kapazitaet  \
# 0        PH08                                               None          -1
# 1        PH06                                Maastrichter Straße         224
# 2        PH07                                      Im Klapperhof         200
# 3        PH10                                     Cäcilienstraße         339
# 4        PH23                                        Lungengasse         191
# 5        PH24                                        Wolfsstraße         315
# 6        PH25                                  Bazaar de Cologne         136
# 7        PH34                                               None          -1
# 8      W_P08W  Stadion P8 PKW - nur bei Veranstaltungen geöffnet          -1
# 9        PH11                                    Galeria Kaufhof         860
# 10       PH12                                        Hohe Straße          90
# 11       PH13                                      Schildergasse         298
# 12       PH14                                   Theater-Parkhaus         340
# 13       PH15                                      Opernpassagen           0
# 14       PH16                                            Maritim          59
# 15       PH17                                        Am Neumarkt         225
# 16       PH18                                     Alte Wallgasse         176
# 17       PH19                                          Gürzenich         187
# 18       PH20                                  Galeria Karstadt          362
# 19       PH21                                     Kreissparkasse         160
# 20       PH22                                           Heumarkt         200
# 21       PH26                                             Quincy         348
# 22       PH27                                 Sparkasse KölnBonn          -1
# 23       PH28                                        P+R Stadion         579
# 24     PH37-2                             Rheinauhafen Bayenturm          60
# 25     PH37-3                       Rheinauhafen Oberländer Wall          20
# 26       PH38                                      Rhein Triadem         261
# 27     W_P001      Stadion P1 - nur bei Veranstaltungen geöffnet         600
# 28     W_P003     Stadion P3  - nur bei Veranstaltungen geöffnet         937
# 29     W_P004      Stadion P4 - nur bei Veranstaltungen geöffnet         500
# 30     W_P006      Stadion P6 - nur bei Veranstaltungen geöffnet        1000
# 31     W_P007      Stadion P7 - nur bei Veranstaltungen geöffnet        1000
# 32     W_P08o  Stadion P8 Bus - nur bei Veranstaltungen geöffnet          40
# 33     D_P001                                    LANXESS arena 1        1640
# 34     D_P002                                    LANXESS arena 2         119
# 35     D_P003                                               None         634
# 36     D_P004                                    LANXESS arena 4         236
# 37     D_P006                                       Köln Arcaden        1391
# 38       PH01                                       Hauptbahnhof         311
# 39       PH02                                             Am Dom         365
# 40       PH03                                  Groß Sankt Martin         101
# 41       PH04                                      Brückenstraße         488
# 42       PH05                                               REWE         186
# 43       PH09                                       Philharmonie         296
# 44       PH29                                Kaiser-Wilhelm-Ring         336
# 45       PH30                                        Rudolfplatz           0
# 46       PH31                                          An Farina         146
# 47       PH33                                          Mediapark         229
# 48       PH35                                Gerling Ring Karree         160
# 49       PH36                                       P+R Marsdorf         610
# 50     PH37-1                                Rheinauhafen Museen          60
# 51       PH32                                          Zoo/Flora          -1
#
#     tendenz         x          y            type
# 0        -1  6.944699  50.944858  parking garage
# 1         0  6.937977  50.938608  parking garage
# 2         0  6.944102  50.942080  parking garage
# 3         0  6.951366  50.934958  parking garage
# 4         0  6.946136  50.934758  parking garage
# 5         0  6.946964  50.937915  parking garage
# 6         0  6.943610  50.937537  parking garage
# 7        -1  7.077462  50.948819  parking garage
# 8        -1  6.867285  50.923908  parking garage
# 9         0  6.954936  50.935512  parking garage
# 10        0  6.956969  50.938818  parking garage
# 11        0  6.951156  50.935623  parking garage
# 12        0  6.949833  50.937198  parking garage
# 13        0  6.952264  50.938733  parking garage
# 14        0  6.962193  50.935596  parking garage
# 15        0  6.947312  50.934766  parking garage
# 16        0  6.942466  50.939835  parking garage
# 17        0  6.957815  50.936953  parking garage
# 18        0  6.947997  50.938493  parking garage
# 19        0  6.947375  50.937201  parking garage
# 20        0  6.961609  50.936459  parking garage
# 21        0  6.950300  50.939400  parking garage
# 22       -1  6.941343  50.935120  parking garage
# 23        0  6.874751  50.937498  parking garage
# 24       -1  6.963970  50.927294  parking garage
# 25       -1  6.968406  50.921036  parking garage
# 26        0  6.961737  50.944105  parking garage
# 27        0  6.884156  50.939818  parking garage
# 28        0  6.869059  50.938925  parking garage
# 29        0  6.873304  50.939226  parking garage
# 30        0  6.868007  50.927534  parking garage
# 31        0  6.868302  50.925815  parking garage
# 32        0  6.868868  50.924121  parking garage
# 33        0  6.983333  50.938962  parking garage
# 34        0  6.980212  50.938736  parking garage
# 35        0  6.983513  50.938070  parking garage
# 36        0  6.985110  50.938893  parking garage
# 37        0  6.997586  50.938167  parking garage
# 38        0  6.960058  50.943543  parking garage
# 39        0  6.959640  50.940297  parking garage
# 40        0  6.960438  50.939874  parking garage
# 41        0  6.955147  50.937442  parking garage
# 42        0  6.956658  50.935552  parking garage
# 43        0  6.961411  50.940455  parking garage
# 44        0  6.941856  50.943669  parking garage
# 45        0  6.938215  50.935998  parking garage
# 46        2  6.957707  50.938338  parking garage
# 47        2  6.944547  50.947637  parking garage
# 48        0  6.940882  50.941263  parking garage
# 49        0  6.848318  50.916253  parking garage
# 50       -1  6.962960  50.931410  parking garage
# 51       -1  6.975065  50.957235  parking garage

# %%
with open("park_and_ride.json", "r") as fp:
    df_park_and_ride = json.load(fp)

df_park_and_ride = pd.DataFrame.from_dict(parse_features(df_park_and_ride['features']))
df_park_and_ride['type']='park and ride'
df_park_and_ride
# Out:
#                                                  name  \
# 0          Bensberg, SteinstraÃŸe 30/Kauler StraÃŸe 4
# 1           Merkenich, Spoerkelhof/Edsel-Ford-StraÃŸe
# 2   Nippes S-Bahn, LÃ¤mmerstraÃŸe (gegenÃ¼ber Haus...
# 3                    Ostheim, Frankfurter StraÃŸe 745
# 4                     Porz-Wahn S-Bahn, Am Bahnhof 85
# 5      Porzer StraÃŸe/Rath, Am Rande 4/Porzer StraÃŸe
# 6        Parkhaus Stadion (P2), Aachener StraÃŸe 1003
# 7                                    Stammheim S-Bahn
# 8          SÃ¼rth, BergstraÃŸe (neben Haus Nummer 77)
# 9   Thielenbruch, Thielenbrucher Allee 46/Im Eiche...
# 10  Heimersdorf, Volkhovener Weg/Fritz-Wacker-StraÃŸe
# 11     Weiden West, Aachener StraÃŸe 1420/BonnstraÃŸe
# 12       Westhoven, Berliner StraÃŸe/Schlawer StraÃŸe
# 13  Worringen S-Bahn, BerrischstraÃŸe/Sinnersdorfe...
# 14                                ZÃ¼ndorf, Gartenweg
# 15  BocklemÃ¼nd, Venloer StraÃŸe (neben Haus Numme...
# 16  BrÃ¼ck-Mauspfad, BrÃ¼cker Mauspfad (neben Haus...
# 17  DellbrÃ¼ck, DellbrÃ¼cker HauptstraÃŸe 178/Otti...
# 18                                             Godorf
# 19  Frankfurter StraÃŸe S-Bahn, GotlandstraÃŸe 2/F...
# 20      Marsdorf, Haus Vorst, Emmy-Noether-StraÃŸe 12
# 21                               Heinrich-LÃ¼bke-Ufer
# 22   KÃ¶nigsforst, Rather Mauspfad/RÃ¶srather StraÃŸe
# 23  Longerich S-Bahn, Volkhovener Weg (neben Haus ...
#
#                                               strasse    plz  \
# 0         Bensberg,  SteinstraÃŸe 30/Kauler StraÃŸe 4  51429
# 1           Merkenich, Spoerkelhof/Edsel-Ford-StraÃŸe  50769
# 2   Nippes S-Bahn, LÃ¤mmerstraÃŸe (gegenÃ¼ber Haus...  50739
# 3                    Ostheim, Frankfurter StraÃŸe 745  51107
# 4                     Porz-Wahn S-Bahn, Am Bahnhof 85  51147
# 5      Porzer StraÃŸe/Rath, Am Rande 4/Porzer StraÃŸe  51107
# 6        Parkhaus Stadion (P2), Aachener StraÃŸe 1003  50933
# 7   Stammheim S-Bahn, DÃ¼nnwalder Kommunalweg/HÃ¶h...  50161
# 8          SÃ¼rth, BergstraÃŸe (neben Haus Nummer 77)  50999
# 9   Thielenbruch, Thielenbrucher Allee 46/Im Eiche...  51069
# 10  Heimersdorf, Volkhovener Weg/Fritz-Wacker-StraÃŸe  50767
# 11     Weiden West, Aachener StraÃŸe 1420/BonnstraÃŸe  50859
# 12       Westhoven, Berliner StraÃŸe/Schlawer StraÃŸe  51149
# 13  Worringen S-Bahn, BerrischstraÃŸe/Sinnersdorfe...  50769
# 14                                ZÃ¼ndorf, Gartenweg  51143
# 15  BocklemÃ¼nd, Venloer StraÃŸe (neben Haus Numme...  50829
# 16  BrÃ¼ck-Mauspfad, BrÃ¼cker Mauspfad (neben Haus...  51109
# 17  DellbrÃ¼ck, DellbrÃ¼cker HauptstraÃŸe 178/Otti...  51069
# 18                           Godorf, IndustriestraÃŸe  50997
# 19  Frankfurter StraÃŸe S-Bahn, GotlandstraÃŸe 2/F...  51149
# 20      Marsdorf, Haus Vorst, Emmy-Noether-StraÃŸe 12  50858
# 21           Heinrich-LÃ¼bke-Ufer/MilitÃ¤rringstraÃŸe  50996
# 22   KÃ¶nigsforst, Rather Mauspfad/RÃ¶srather StraÃŸe  51107
# 23  Longerich S-Bahn, Volkhovener Weg (neben Haus ...  50739
#
#                 stadt  stellplaetze  \
# 0   Bergisch Gladbach           127
# 1               KÃ¶ln            15
# 2               KÃ¶ln            27
# 3               KÃ¶ln            23
# 4               KÃ¶ln           298
# 5               KÃ¶ln            23
# 6               KÃ¶ln           571
# 7               KÃ¶ln           202
# 8               KÃ¶ln            72
# 9               KÃ¶ln           149
# 10              KÃ¶ln            42
# 11              KÃ¶ln           685
# 12              KÃ¶ln            42
# 13              KÃ¶ln           197
# 14              KÃ¶ln           117
# 15              KÃ¶ln           280
# 16              KÃ¶ln           355
# 17              KÃ¶ln           339
# 18              KÃ¶ln            70
# 19              KÃ¶ln           134
# 20              KÃ¶ln           621
# 21              KÃ¶ln           128
# 22              KÃ¶ln           180
# 23              KÃ¶ln            68
#
#                                             hyperlink  \
# 0   https://www.kvb.koeln/mobilitaet/park_and_ride...
# 1   https://www.kvb.koeln/mobilitaet/park_and_ride...
# 2   https://www.kvb.koeln/mobilitaet/park_and_ride...
# 3   https://www.kvb.koeln/mobilitaet/park_and_ride...
# 4   https://www.kvb.koeln/mobilitaet/park_and_ride...
# 5   https://www.kvb.koeln/mobilitaet/park_and_ride...
# 6   https://www.kvb.koeln/mobilitaet/park_and_ride...
# 7   https://www.kvb.koeln/mobilitaet/park_and_ride...
# 8   https://www.kvb.koeln/mobilitaet/park_and_ride...
# 9   https://www.kvb.koeln/mobilitaet/park_and_ride...
# 10  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 11  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 12  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 13  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 14  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 15  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 16  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 17  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 18  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 19  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 20  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 21  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 22  https://www.kvb.koeln/mobilitaet/park_and_ride...
# 23  https://www.kvb.koeln/mobilitaet/park_and_ride...
#
#                                       oeffnungszeiten  \
# 0   Ã–ffnungszeiten: tÃ¤glich 24 Stunden Serviceze...
# 1                Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 2                Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 3                Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 4   Ã–ffnungszeiten: tÃ¤glich 24 Stunden Serviceze...
# 5                Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 6   Ã–ffnungszeiten: 24 Stunden Servicezeiten: Mon...
# 7                Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 8   Einfahrt zwischen 6 und 22 Uhr mÃ¶glich (24 St...
# 9                Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 10               Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 11               Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 12               Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 13               Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 14               Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 15  Ã–ffnungszeiten: 24 Stunden Servicezeiten: Mon...
# 16  Ã–ffnungszeiten: 24 Stunden Servicezeiten: Mon...
# 17  Ã–ffnungszeiten: tÃ¤glich 24 Stunden Serviceze...
# 18               Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 19               Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 20  Ã–ffnungszeiten: tÃ¤glich 24 Stunden Serviceze...
# 21               Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 22               Ã–ffnungszeiten: tÃ¤glich 24 Stunden
# 23               Ã–ffnungszeiten: tÃ¤glich 24 Stunden
#
#                                          verbindungen  objectid         x  \
# 0                  Anbindung an die Stadtbahn-Linie 1       321  7.161690
# 1         Anbindung an die Stadtbahn-Linien 12 und 18         2  6.948074
# 2             Anbindung an die S-Bahn-Linien 6 und 11         3  6.940826
# 3                  Anbindung an die Stadtbahn-Linie 9         4  7.042176
# 4            Anbindung an die S-Bahn-Linien 12 und 19         6  7.078638
# 5                  Anbindung an die Stadtbahn-Linie 9         7  7.074707
# 6                  Anbindung an die Stadtbahn-Linie 1         9  6.874680
# 7                     Anbindung an die S-Bahn-Linie 6        10  7.002795
# 8                 Anbindung an die Stadtbahn-Linie 16        11  7.003616
# 9          Anbindung an die Stadtbahn-Linien 3 und 18        12  7.087571
# 10                   Anbindung an die S-Bahn-Linie 11        13  6.892346
# 11  Anbindung an die Stadtbahn-Linie 1 sowie die S...        14  6.814912
# 12                 Anbindung an die Stadtbahn-Linie 7        16  7.025771
# 13                   Anbindung an die S-Bahn-Linie 11        17  6.850466
# 14                 Anbindung an die Stadtbahn-Linie 7        20  7.050281
# 15          Anbindung an die Stadtbahn-Linien 3 und 4        22  6.873109
# 16                 Anbindung an die Stadtbahn-Linie 1        23  7.077089
# 17         Anbindung an die Stadtbahn-Linien 3 und 18        25  7.069463
# 18                Anbindung an die Stadtbahn-Linie 16        30  6.978689
# 19               Anbindung an die Linien S19 und RB25        31  7.053797
# 20                 Anbindung an die Stadtbahn-Linie 7        32  6.848002
# 21                Anbindung an die Stadtbahn-Linie 16        33  6.985539
# 22                 Anbindung an die Stadtbahn-Linie 9        38  7.097656
# 23            Anbindung an die S-Bahn-Linien 6 und 11        42  6.901554
#
#             y           type
# 0   50.963347  park and ride
# 1   51.028448  park and ride
# 2   50.957570  park and ride
# 3   50.928769  park and ride
# 4   50.859983  park and ride
# 5   50.921752  park and ride
# 6   50.937380  park and ride
# 7   50.989607  park and ride
# 8   50.863912  park and ride
# 9   50.978017  park and ride
# 10  51.013673  park and ride
# 11  50.939534  park and ride
# 12  50.901089  park and ride
# 13  51.052114  park and ride
# 14  50.866795  park and ride
# 15  50.969635  park and ride
# 16  50.949024  park and ride
# 17  50.981152  park and ride
# 18  50.848255  park and ride
# 19  50.916219  park and ride
# 20  50.916160  park and ride
# 21  50.899426  park and ride
# 22  50.919358  park and ride
# 23  50.999304  park and ride

# %%
df_parking_meter = pd.read_csv("parking_meter_2020.csv", sep=';')
df_parking_meter
# Out:
#       PSA-Nr.          Aufstellort        Bezirk/Gebiet  \
# 0           1  Deutzer Freiheit 53              Deutz I
# 1           2     Offenbachplatz 3  City/Martinsviertel
# 2           3           Turkuplatz           Chorweiler
# 3           4     Neusser Str. 453               Nippes
# 4           5  Liverpooler Platz A           Chorweiler
# ...       ...                  ...                  ...
# 2781     2782    Aachener Str. 458           Lindenthal
# 2782     2783    Aachener Str. 448           Lindenthal
# 2783     2784    Aachener Str. 514           Lindenthal
# 2784     2785    Aachener Str. 515           Lindenthal
# 2785     2786    Aachener Str. 543           Lindenthal
#
#                  Abschnitt/-von               Abschnitt/-bis  Stellplätze  \
# 0               Siegburger Str.                   Düppelstr.          9.0
# 1                           NaN                          NaN          8.0
# 2                  Athener Ring             Willi-Suth-Allee         33.0
# 3                    Bergstraße           Mauenheimer Gürtel         14.0
# 4                   Platzfläche                          NaN         45.0
# ...                         ...                          ...          ...
# 2781            Eschweiler Str.  Peter von Fliesteden-Straße          6.0
# 2782  Peter von Fliesteden Str.            Burtscheider Str.         13.0
# 2783               Eupener Str.            Burtscheider Str.         10.0
# 2784                  Braunstr.            Kitschburger Str.          3.0
# 2785       Hermann-Pflaume-Str.                    Braunstr.         11.0
#
#      Roter Punkt                                  Gebuehrenzeit  \
# 0            NaN                            Mo-Sa 09:00 - 21:00
# 1           CITY                            Mo-Sa 09:00 - 23:00
# 2            NaN                            Mo-Sa 09:00 - 20:00
# 3            NaN                            Mo-Sa 09:00 - 18:00
# 4            NaN  Mo-Mi+Fr 09:00 - 20:00; Do + Sa 15:00 - 20:00
# ...          ...                                            ...
# 2781         NaN                            Mo-Sa 09:00 - 18:00
# 2782         NaN                            Mo-Sa 09:00 - 18:00
# 2783         NaN                            Mo-Sa 09:00 - 18:00
# 2784         NaN                            Mo-Sa 09:00 - 18:00
# 2785         NaN                            Mo-Sa 09:00 - 18:00
#
#      Gebuehr je 15 Minuten  HPD/Std. Tagesgebuehr  Tarifzone  \
# 0                   1,00 €         2          NaN     500070
# 1                   1,00 €         4          NaN     500002
# 2                   0,50 €         4          NaN     500022
# 3                   0,50 €         4          NaN     500003
# 4                   0,50 €         4          NaN     500028
# ...                    ...       ...          ...        ...
# 2781                0,50 €         4          NaN     500003
# 2782                0,50 €         4          NaN     500003
# 2783                0,50 €         4          NaN     500003
# 2784                0,50 €         4          NaN     500003
# 2785                0,50 €         4          NaN     500003
#
#      GeoKoordinateNord GeoKoordinateOst
# 0          50,93686078       6,97249396
# 1             50,93795          6,95324
# 2          51,01951411       6,89767251
# 3          50,97248481       6,95098355
# 4            51,021261         6,898092
# ...                ...              ...
# 2781               NaN              NaN
# 2782               NaN              NaN
# 2783               NaN              NaN
# 2784               NaN              NaN
# 2785               NaN              NaN
#
# [2786 rows x 14 columns]

# %% [markdown]
# We have to rename GeoKoordinateNord and GeoKoordinateOst to y and x respectively to aling them with other data we have

# %%
df_parking_meter = df_parking_meter.rename(columns={'GeoKoordinateOst': 'x', 'GeoKoordinateNord': 'y'})
df_parking_meter['type']='parking meter'
df_parking_meter
# Out:
#       PSA-Nr.          Aufstellort        Bezirk/Gebiet  \
# 0           1  Deutzer Freiheit 53              Deutz I
# 1           2     Offenbachplatz 3  City/Martinsviertel
# 2           3           Turkuplatz           Chorweiler
# 3           4     Neusser Str. 453               Nippes
# 4           5  Liverpooler Platz A           Chorweiler
# ...       ...                  ...                  ...
# 2781     2782    Aachener Str. 458           Lindenthal
# 2782     2783    Aachener Str. 448           Lindenthal
# 2783     2784    Aachener Str. 514           Lindenthal
# 2784     2785    Aachener Str. 515           Lindenthal
# 2785     2786    Aachener Str. 543           Lindenthal
#
#                  Abschnitt/-von               Abschnitt/-bis  Stellplätze  \
# 0               Siegburger Str.                   Düppelstr.          9.0
# 1                           NaN                          NaN          8.0
# 2                  Athener Ring             Willi-Suth-Allee         33.0
# 3                    Bergstraße           Mauenheimer Gürtel         14.0
# 4                   Platzfläche                          NaN         45.0
# ...                         ...                          ...          ...
# 2781            Eschweiler Str.  Peter von Fliesteden-Straße          6.0
# 2782  Peter von Fliesteden Str.            Burtscheider Str.         13.0
# 2783               Eupener Str.            Burtscheider Str.         10.0
# 2784                  Braunstr.            Kitschburger Str.          3.0
# 2785       Hermann-Pflaume-Str.                    Braunstr.         11.0
#
#      Roter Punkt                                  Gebuehrenzeit  \
# 0            NaN                            Mo-Sa 09:00 - 21:00
# 1           CITY                            Mo-Sa 09:00 - 23:00
# 2            NaN                            Mo-Sa 09:00 - 20:00
# 3            NaN                            Mo-Sa 09:00 - 18:00
# 4            NaN  Mo-Mi+Fr 09:00 - 20:00; Do + Sa 15:00 - 20:00
# ...          ...                                            ...
# 2781         NaN                            Mo-Sa 09:00 - 18:00
# 2782         NaN                            Mo-Sa 09:00 - 18:00
# 2783         NaN                            Mo-Sa 09:00 - 18:00
# 2784         NaN                            Mo-Sa 09:00 - 18:00
# 2785         NaN                            Mo-Sa 09:00 - 18:00
#
#      Gebuehr je 15 Minuten  HPD/Std. Tagesgebuehr  Tarifzone            y  \
# 0                   1,00 €         2          NaN     500070  50,93686078
# 1                   1,00 €         4          NaN     500002     50,93795
# 2                   0,50 €         4          NaN     500022  51,01951411
# 3                   0,50 €         4          NaN     500003  50,97248481
# 4                   0,50 €         4          NaN     500028    51,021261
# ...                    ...       ...          ...        ...          ...
# 2781                0,50 €         4          NaN     500003          NaN
# 2782                0,50 €         4          NaN     500003          NaN
# 2783                0,50 €         4          NaN     500003          NaN
# 2784                0,50 €         4          NaN     500003          NaN
# 2785                0,50 €         4          NaN     500003          NaN
#
#                x           type
# 0     6,97249396  parking meter
# 1        6,95324  parking meter
# 2     6,89767251  parking meter
# 3     6,95098355  parking meter
# 4       6,898092  parking meter
# ...          ...            ...
# 2781         NaN  parking meter
# 2782         NaN  parking meter
# 2783         NaN  parking meter
# 2784         NaN  parking meter
# 2785         NaN  parking meter
#
# [2786 rows x 15 columns]

# %% [markdown]
# chargin_station.csv had a header consisting of 10 rows which was removed manually in libreoffice to make it easy to read with pandas

# %%
df_charging_station = pd.read_csv('charging_station_edited.csv', sep=';', encoding='latin1')
df_charging_station.iloc[0]
# Out:
# Betreiber                     Albwerk GmbH & Co. KG
# Straße                               Ennabeurer Weg
# Hausnummer                                        0
# Adresszusatz                                    NaN
# Postleitzahl                                  72535
# Ort                                     Heroldstatt
# Bundesland                        Baden-Württemberg
# Kreis/kreisfreie Stadt    Landkreis Alb-Donau-Kreis
# Breitengrad                               48.442398
# Längengrad                                 9.659075
# Inbetriebnahmedatum                      11.01.2020
# Anschlussleistung                              22.0
# Art der Ladeeinrichung        Normalladeeinrichtung
# Anzahl Ladepunkte                                 2
# Steckertypen1                    AC Steckdose Typ 2
# P1 [kW]                                        22.0
# Public Key1                                     NaN
# Steckertypen2                    AC Steckdose Typ 2
# P2 [kW]                                        22.0
# Public Key2                                     NaN
# Steckertypen3                                   NaN
# P3 [kW]                                         NaN
# Public Key3                                     NaN
# Steckertypen4                                   NaN
# P4 [kW]                                         NaN
# Public Key4                                     NaN
# Name: 0, dtype: object

# %%
df_charging_station = df_charging_station.rename(columns={'Breitengrad':'x', 'Längengrad':'y'})
df_charging_station['type'] = 'charging station'
df_charging_station.iloc[1]
# Out:
# Betreiber                     Albwerk GmbH & Co. KG
# Straße                       Parkplatz Campingplatz
# Hausnummer                                        0
# Adresszusatz                                    NaN
# Postleitzahl                                  72589
# Ort                                      Westerheim
# Bundesland                        Baden-Württemberg
# Kreis/kreisfreie Stadt    Landkreis Alb-Donau-Kreis
# x                                           48.5105
# y                                             9.609
# Inbetriebnahmedatum                      07.01.2019
# Anschlussleistung                              22.0
# Art der Ladeeinrichung        Normalladeeinrichtung
# Anzahl Ladepunkte                                 2
# Steckertypen1                    AC Steckdose Typ 2
# P1 [kW]                                        22.0
# Public Key1                                     NaN
# Steckertypen2                    AC Steckdose Typ 2
# P2 [kW]                                        22.0
# Public Key2                                     NaN
# Steckertypen3                                   NaN
# P3 [kW]                                         NaN
# Public Key3                                     NaN
# Steckertypen4                                   NaN
# P4 [kW]                                         NaN
# Public Key4                                     NaN
# type                               charging station
# Name: 1, dtype: object

# %% [markdown]
# ### Merge all of them to one dataframe

# %%
df_merged = df_disabled_parking.append(df_park_and_ride).append(df_parking_meter).append(df_parking_garages).append(df_charging_station)
df_merged
# Out:
#        objectid                     bezeichnung nr_stadtbezirk stadtteil  \
# 0           1.0            Am Schwanebitzer Hof              7    Urbach
# 1           2.0                  DÃ¼lkenstr. 18              7      Porz
# 2           3.0            Friedrich-Ebert-Ufer              7      Porz
# 3           4.0                     GÃ¼tergasse              7  ZÃ¼ndorf
# 4           5.0  Heidestr. (vor Raiffeisenbank)              7      Wahn
# ...         ...                             ...            ...       ...
# 30393       NaN                             NaN            NaN       NaN
# 30394       NaN                             NaN            NaN       NaN
# 30395       NaN                             NaN            NaN       NaN
# 30396       NaN                             NaN            NaN       NaN
# 30397       NaN                             NaN            NaN       NaN
#
#        anzahl                       bemerkung          x          y  \
# 0         1.0            Am Schwanebitzer Hof   7.080333  50.882116
# 1         2.0                  DÃ¼lkenstr. 18   7.052518  50.890363
# 2         1.0            Friedrich-Ebert-Ufer   7.054507  50.883369
# 3         1.0                     GÃ¼tergasse    7.04546  50.869548
# 4         1.0  Heidestr. (vor Raiffeisenbank)   7.087442  50.857666
# ...       ...                             ...        ...        ...
# 30393     NaN                             NaN  51.021253  11.513847
# 30394     NaN                             NaN  51.020983   11.51048
# 30395     NaN                             NaN  51.107188  11.659489
# 30396     NaN                             NaN  51.092527  11.628574
# 30397     NaN                             NaN   53.87122   13.92683
#
#                         type name  ...  \
# 0      disabled parking slot  NaN  ...
# 1      disabled parking slot  NaN  ...
# 2      disabled parking slot  NaN  ...
# 3      disabled parking slot  NaN  ...
# 4      disabled parking slot  NaN  ...
# ...                      ...  ...  ...
# 30393       charging station  NaN  ...
# 30394       charging station  NaN  ...
# 30395       charging station  NaN  ...
# 30396       charging station  NaN  ...
# 30397       charging station  NaN  ...
#
#                                              Public Key1       Steckertypen2  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4                                                    NaN                 NaN
# ...                                                  ...                 ...
# 30393                                                NaN  AC Steckdose Typ 2
# 30394                                                NaN                 NaN
# 30395  3059301306072A8648CE3D020106082A8648CE3D030107...  AC Steckdose Typ 2
# 30396                                                NaN  AC Steckdose Typ 2
# 30397  AF4E CF94 77F7 84E2 2AF1 8E1B C271 447E 38AD 6...  AC Steckdose Typ 2
#
#       P2 [kW]                                        Public Key2  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
# ...       ...                                                ...
# 30393    22.0                                                NaN
# 30394     NaN                                                NaN
# 30395    22.0  3059301306072A8648CE3D020106082A8648CE3D030107...
# 30396    22.0                                                NaN
# 30397    22.0  D535 071A C744 E295 E655 7DCA 11E3  8232 1733 ...
#
#       Steckertypen3 P3 [kW] Public Key3  Steckertypen4 P4 [kW] Public Key4
# 0               NaN     NaN         NaN            NaN     NaN         NaN
# 1               NaN     NaN         NaN            NaN     NaN         NaN
# 2               NaN     NaN         NaN            NaN     NaN         NaN
# 3               NaN     NaN         NaN            NaN     NaN         NaN
# 4               NaN     NaN         NaN            NaN     NaN         NaN
# ...             ...     ...         ...            ...     ...         ...
# 30393           NaN     NaN         NaN            NaN     NaN         NaN
# 30394           NaN     NaN         NaN            NaN     NaN         NaN
# 30395           NaN     NaN         NaN            NaN     NaN         NaN
# 30396           NaN     NaN         NaN            NaN     NaN         NaN
# 30397           NaN     NaN         NaN            NaN     NaN         NaN
#
# [33685 rows x 57 columns]

# %%
df_merged.to_csv('merged_data.csv')
